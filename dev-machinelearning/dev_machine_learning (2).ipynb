# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input, Flatten, Conv2D, MaxPooling2D, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import numpy as np
import cv2
from PIL import Image
import tensorflow as tf
import os
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.callbacks import ModelCheckpoint,ReduceLROnPlateau

# %%
# def train_val_spliter(dirname, foldername, classes, rate=0.8):
#   count = 0
#   datapath = os.getcwd()
#   i = 0
#   for (path, dic, files) in os.walk(dirname):
#     if path.split('\\')[-1] == classes:
#       number = len(files)
#       for filename in files:
#         ext = os.path.splitext(filename)[-1]
#         if ext == '.jpg':
#           if count < number * rate:
#             image = cv2.imread(dirname +'/'+classes+'/'+filename)
#             cv2.imwrite(datapath + '/' + foldername + '/' + 'train' + '/' + classes + '/' + filename, image)
#           else:
#             image = cv2.imread(dirname + '/' +classes+'/' +filename)
#             cv2.imwrite(datapath + '/' + foldername + '/' + 'valid' + '/' + classes + '/' + filename, image)
#         count += 1
# def makedirs(dirname, classes):
#   path = os.getcwd()
#   if not os.path.isdir(path +'/' + dirname):
#     os.makedirs(path + '/' + dirname)
#   if not os.path.isdir(path +'/' + dirname + '/' + 'train'):
#     os.makedirs(path + '/' + dirname + '/' + 'train')
#   if not os.path.isdir(path +'/' + dirname + '/' + 'valid'):
#     os.makedirs(path + '/' + dirname + '/' + 'valid')
#   if not os.path.isdir(path +'/' + dirname + '/' + 'train' + '/' + classes):
#     os.makedirs(path +'/' + dirname + '/' + 'train' + '/' + classes)
#   if not os.path.isdir(path +'/' + dirname + '/' + 'valid' + '/' + classes):
#     os.makedirs(path + '/' + dirname + '/' + 'valid' + '/' + classes)

# %%
# makedirs('dev_image', 'dog')
# makedirs('dev_image', 'elephant')
# makedirs('dev_image', 'giraffe')
# makedirs('dev_image', 'guitar')
# makedirs('dev_image', 'horse')
# makedirs('dev_image', 'house')
# makedirs('dev_image', 'person')

# path = 'C:\\Users\\subak\\PycharmProjects\\project20210517\\dev_machinelearning\\train'
# train_val_spliter(path, 'dev_image', 'dog')
# train_val_spliter(path, 'dev_image', 'elephant')
# train_val_spliter(path, 'dev_image', 'giraffe')
# train_val_spliter(path, 'dev_image', 'guitar')
# train_val_spliter(path, 'dev_image', 'horse')
# train_val_spliter(path, 'dev_image', 'house')
# train_val_spliter(path, 'dev_image', 'person')

# %%
def plot_loss(history):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epochs')
    plt.legend(['Train', 'val'], loc=0)

def plot_acc(history):
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epochs')
    plt.legend(['Train', 'val'], loc=0)

# %%
# from tensorflow.keras import Sequential
# from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Activation, Input, Conv3D, Add, LeakyReLU,AveragePooling2D
# from tensorflow.keras.models import Model
# from tensorflow.keras.optimizers import SGD
# import matplotlib.pyplot as plt
# from tensorflow.keras.regularizers import l2


# def residual_block(x, filters_in, filters_out, k_size):
#     shortcut = x
#     x = Conv2D(filters_in, kernel_size=(1, 1), strides=(1, 1), padding="same")(x)
#     x = BatchNormalization()(x)
#     x = LeakyReLU()(x)

#     x = Conv2D(filters_in, kernel_size=(k_size, k_size), strides=(1, 1), padding="same")(x)
#     x = BatchNormalization()(x)
#     x = LeakyReLU()(x)

#     x = Conv2D(filters_out, kernel_size=(1, 1), strides=(1, 1), padding="same")(x)
#     x = BatchNormalization()(x)

#     shortcut_channel = shortcut.shape.as_list()[-1]

#     if shortcut_channel != filters_out:
#         shortcut = Conv2D(filters_out, kernel_size=(1, 1), strides=(1, 1), padding="same")(shortcut)

#     x = Add()([x, shortcut])
#     return LeakyReLU()(x)

# def define_model(image_height, image_width, image_channel, classes):
#     input_tensor = Input(shape=(image_height, image_width, image_channel))
#     x = Conv2D(64, kernel_size=(7, 7), strides=2, padding='same',
#                kernel_initializer='he_normal')(input_tensor)
#     x = BatchNormalization()(x)
#     x = Activation('relu')(x)
#     x = MaxPooling2D(pool_size=(3, 3), strides=2, padding='same')(x)
#     x = residual_block(x, 64, 256, 3)
#     x = MaxPooling2D(pool_size=(2, 2))(x)
#     x = residual_block(x, 128, 512, 3)
#     x = AveragePooling2D(pool_size=(2,2))(x)
#     x = Flatten()(x)
#     x = Dropout(0.5)(x)
#     output_tensor = Dense(classes, activation='softmax')(x)
#     model = Model(inputs=input_tensor, outputs=output_tensor)
#     model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
#     return model

# %%
# def define_model(image_height, image_width, image_channel, classes):
#   input = Input(shape=(image_height, image_width, image_channel))
#   model = ResNet50(input_tensor=input, include_top=False, weights='imagenet', pooling='max')
 
#   x = model.output
#   x = Dense(1024)(x)
#   x = BatchNormalization()(x)
#   x = Activation('relu')(x)
#   x = Dense(512)(x)
#   x = BatchNormalization()(x)
#   x = Activation('relu')(x)
#   x = Dropout(0.5)(x)
#   x = Dense(classes, activation='softmax')(x)
#   model = Model(model.input, x)
#   model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
#   return model

# %%
def define_model(image_height, image_width, image_channel, classes):
  input = Input(shape=(image_height, image_width, image_channel))
  model = ResNet50(input_tensor=input, include_top=False, weights='imagenet', pooling='max')
  additional_model = Sequential()
  additional_model.add(model)
  additional_model.add(Flatten())
  additional_model.add(Dense(2048, activation='relu'))
  additional_model.add(Dense(1024, activation='relu'))
  additional_model.add(Dropout(0.5))
  additional_model.add(Dense(7, activation='softmax'))
  additional_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
  return additional_model

# %%
model = define_model(227, 227, 3, 7)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 2048)              4196352
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 7175
# =================================================================
# Total params: 29,889,415
# Trainable params: 29,836,295
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1.0 / 255.0,
                                   shear_range=20,featurewise_std_normalization=True, rotation_range = 90, vertical_flip=True, brightness_range=[0.2, 1.0], zoom_range=[0.5, 1.5])
test_datagen = ImageDataGenerator(rescale=1.0 / 255.0)

train_it = train_datagen.flow_from_directory('/content/drive/MyDrive/dev_machinelearning/train',
                                       class_mode='categorical', batch_size=32, target_size=(227, 227))
# Out:
# Found 1652 images belonging to 7 classes.
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:349: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, which overrides setting of `featurewise_center`.
#   warnings.warn('This ImageDataGenerator specifies '

# %%
# from tensorflow.keras.models import load_model
# model = load_model('3-1.34.h5')

# %%
model_checkpoint = ModelCheckpoint(filepath='./{epoch}-{loss:.2f}.h5', monitor='loss', save_best_only=True, verbose=1)
reduceLR = ReduceLROnPlateau(
    monitor='loss',  # 검증 손실을 기준으로 callback이 호출됩니다
    factor=0.5,          # callback 호출시 학습률을 1/2로 줄입니다
    patience=10         # epoch 10 동안 개선되지 않으면 callback이 호출됩니다
)

# %%
history = model.fit_generator(train_it, steps_per_epoch=len(train_it),
                             epochs=100, verbose=1, callbacks=[model_checkpoint,reduceLR])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:728: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# Epoch 1/100
# 52/52 [==============================] - 27s 515ms/step - loss: 1.4527 - accuracy: 0.4740
#
# Epoch 00001: loss improved from inf to 1.45270, saving model to ./1-1.45.h5
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/100
# 52/52 [==============================] - 27s 513ms/step - loss: 1.4059 - accuracy: 0.5097
#
# Epoch 00002: loss improved from 1.45270 to 1.40590, saving model to ./2-1.41.h5
# Epoch 3/100
# 52/52 [==============================] - 27s 515ms/step - loss: 1.3352 - accuracy: 0.5169
#
# Epoch 00003: loss improved from 1.40590 to 1.33524, saving model to ./3-1.34.h5
# Epoch 4/100
# 52/52 [==============================] - 27s 517ms/step - loss: 1.3436 - accuracy: 0.5200
#
# Epoch 00004: loss did not improve from 1.33524
# Epoch 5/100
# 52/52 [==============================] - 27s 512ms/step - loss: 1.4451 - accuracy: 0.4679
#
# Epoch 00005: loss did not improve from 1.33524
# Epoch 6/100
# 52/52 [==============================] - 27s 515ms/step - loss: 1.4254 - accuracy: 0.4843
#
# Epoch 00006: loss did not improve from 1.33524
# Epoch 7/100
# 52/52 [==============================] - 27s 513ms/step - loss: 1.4349 - accuracy: 0.4770
#
# Epoch 00007: loss did not improve from 1.33524
# Epoch 8/100
# 52/52 [==============================] - 27s 513ms/step - loss: 1.3674 - accuracy: 0.5127
#
# Epoch 00008: loss did not improve from 1.33524
# Epoch 9/100
# 52/52 [==============================] - 27s 515ms/step - loss: 1.3425 - accuracy: 0.5200
#
# Epoch 00009: loss did not improve from 1.33524
# Epoch 10/100
# 52/52 [==============================] - 27s 516ms/step - loss: 1.3255 - accuracy: 0.5224
#
# Epoch 00010: loss improved from 1.33524 to 1.32546, saving model to ./10-1.33.h5
# Epoch 11/100
# 52/52 [==============================] - 27s 516ms/step - loss: 1.3117 - accuracy: 0.5309
#
# Epoch 00011: loss improved from 1.32546 to 1.31168, saving model to ./11-1.31.h5
# Epoch 12/100
# 52/52 [==============================] - 27s 515ms/step - loss: 1.3193 - accuracy: 0.5248
#
# Epoch 00012: loss did not improve from 1.31168
# Epoch 13/100
# 52/52 [==============================] - 27s 516ms/step - loss: 1.2171 - accuracy: 0.5623
#
# Epoch 00013: loss improved from 1.31168 to 1.21713, saving model to ./13-1.22.h5
# Epoch 14/100
# 52/52 [==============================] - 27s 514ms/step - loss: 1.3112 - accuracy: 0.5188
#
# Epoch 00014: loss did not improve from 1.21713
# Epoch 15/100
# 52/52 [==============================] - 27s 514ms/step - loss: 1.3310 - accuracy: 0.5176
#
# Epoch 00015: loss did not improve from 1.21713
# Epoch 16/100
# 52/52 [==============================] - 27s 517ms/step - loss: 1.3650 - accuracy: 0.5018
#
# Epoch 00016: loss did not improve from 1.21713
# Epoch 17/100
# 52/52 [==============================] - 27s 521ms/step - loss: 1.4508 - accuracy: 0.4691
#
# Epoch 00017: loss did not improve from 1.21713
# Epoch 18/100
# 52/52 [==============================] - 27s 514ms/step - loss: 1.4328 - accuracy: 0.4776
#
# Epoch 00018: loss did not improve from 1.21713
# Epoch 19/100
# 52/52 [==============================] - 27s 516ms/step - loss: 1.3404 - accuracy: 0.5272
#
# Epoch 00019: loss did not improve from 1.21713
# Epoch 20/100
# 52/52 [==============================] - 27s 516ms/step - loss: 1.2690 - accuracy: 0.5539
#
# Epoch 00020: loss did not improve from 1.21713
# Epoch 21/100
# 52/52 [==============================] - 27s 517ms/step - loss: 1.2514 - accuracy: 0.5575
#
# Epoch 00021: loss did not improve from 1.21713
# Epoch 22/100
# 52/52 [==============================] - 27s 516ms/step - loss: 1.2598 - accuracy: 0.5460
#
# Epoch 00022: loss did not improve from 1.21713
# Epoch 23/100
# 52/52 [==============================] - 27s 515ms/step - loss: 1.2398 - accuracy: 0.5508
#
# Epoch 00023: loss did not improve from 1.21713
# Epoch 24/100
# 52/52 [==============================] - 27s 513ms/step - loss: 1.1232 - accuracy: 0.5823
#
# Epoch 00024: loss improved from 1.21713 to 1.12322, saving model to ./24-1.12.h5
# Epoch 25/100
# 52/52 [==============================] - 27s 516ms/step - loss: 1.1248 - accuracy: 0.5775
#
# Epoch 00025: loss did not improve from 1.12322
# Epoch 26/100
# 52/52 [==============================] - 27s 513ms/step - loss: 1.0645 - accuracy: 0.6102
#
# Epoch 00026: loss improved from 1.12322 to 1.06452, saving model to ./26-1.06.h5
# Epoch 27/100
# 52/52 [==============================] - 27s 515ms/step - loss: 1.0330 - accuracy: 0.6186
#
# Epoch 00027: loss improved from 1.06452 to 1.03304, saving model to ./27-1.03.h5
# Epoch 28/100
# 52/52 [==============================] - 27s 513ms/step - loss: 0.9900 - accuracy: 0.6326
#
# Epoch 00028: loss improved from 1.03304 to 0.99000, saving model to ./28-0.99.h5
# Epoch 29/100
# 52/52 [==============================] - 27s 513ms/step - loss: 1.0379 - accuracy: 0.6289
#
# Epoch 00029: loss did not improve from 0.99000
# Epoch 30/100
# 52/52 [==============================] - 27s 515ms/step - loss: 0.9888 - accuracy: 0.6459
#
# Epoch 00030: loss improved from 0.99000 to 0.98884, saving model to ./30-0.99.h5
# Epoch 31/100
# 52/52 [==============================] - 27s 515ms/step - loss: 0.9931 - accuracy: 0.6447
#
# Epoch 00031: loss did not improve from 0.98884
# Epoch 32/100
# 52/52 [==============================] - 27s 512ms/step - loss: 1.0022 - accuracy: 0.6332
#
# Epoch 00032: loss did not improve from 0.98884
# Epoch 33/100
# 52/52 [==============================] - 27s 516ms/step - loss: 0.9316 - accuracy: 0.6646
#
# Epoch 00033: loss improved from 0.98884 to 0.93162, saving model to ./33-0.93.h5
# Epoch 34/100
# 52/52 [==============================] - 27s 512ms/step - loss: 0.9265 - accuracy: 0.6653
#
# Epoch 00034: loss improved from 0.93162 to 0.92650, saving model to ./34-0.93.h5
# Epoch 35/100
# 52/52 [==============================] - 27s 513ms/step - loss: 0.9723 - accuracy: 0.6277
#
# Epoch 00035: loss did not improve from 0.92650
# Epoch 36/100
# 52/52 [==============================] - 27s 516ms/step - loss: 0.9948 - accuracy: 0.6374
#
# Epoch 00036: loss did not improve from 0.92650
# Epoch 37/100
# 52/52 [==============================] - 27s 512ms/step - loss: 0.9975 - accuracy: 0.6362
#
# Epoch 00037: loss did not improve from 0.92650
# Epoch 38/100
# 52/52 [==============================] - 27s 512ms/step - loss: 0.9016 - accuracy: 0.6883
#
# Epoch 00038: loss improved from 0.92650 to 0.90157, saving model to ./38-0.90.h5
# Epoch 39/100
# 52/52 [==============================] - 27s 514ms/step - loss: 1.0333 - accuracy: 0.6150
#
# Epoch 00039: loss did not improve from 0.90157
# Epoch 40/100
# 52/52 [==============================] - 27s 513ms/step - loss: 0.9867 - accuracy: 0.6556
#
# Epoch 00040: loss did not improve from 0.90157
# Epoch 41/100
# 52/52 [==============================] - 27s 513ms/step - loss: 0.9349 - accuracy: 0.6646
#
# Epoch 00041: loss did not improve from 0.90157
# Epoch 42/100
# 52/52 [==============================] - 27s 515ms/step - loss: 0.9158 - accuracy: 0.6737
#
# Epoch 00042: loss did not improve from 0.90157
# Epoch 43/100
# 52/52 [==============================] - 27s 513ms/step - loss: 0.9955 - accuracy: 0.6501
#
# Epoch 00043: loss did not improve from 0.90157
# Epoch 44/100
# 52/52 [==============================] - 27s 512ms/step - loss: 0.8859 - accuracy: 0.6840
#
# Epoch 00044: loss improved from 0.90157 to 0.88586, saving model to ./44-0.89.h5
# Epoch 45/100
# 52/52 [==============================] - 27s 517ms/step - loss: 0.9544 - accuracy: 0.6568
#
# Epoch 00045: loss did not improve from 0.88586
# Epoch 46/100
# 52/52 [==============================] - 27s 512ms/step - loss: 1.0055 - accuracy: 0.6459
#
# Epoch 00046: loss did not improve from 0.88586
# Epoch 47/100
# 52/52 [==============================] - 27s 512ms/step - loss: 0.9646 - accuracy: 0.6459
#
# Epoch 00047: loss did not improve from 0.88586
# Epoch 48/100
# 52/52 [==============================] - 27s 515ms/step - loss: 0.8715 - accuracy: 0.6864
#
# Epoch 00048: loss improved from 0.88586 to 0.87150, saving model to ./48-0.87.h5
# Epoch 49/100
# 52/52 [==============================] - 27s 511ms/step - loss: 0.8891 - accuracy: 0.6858
#
# Epoch 00049: loss did not improve from 0.87150
# Epoch 50/100
# 52/52 [==============================] - 27s 512ms/step - loss: 0.8775 - accuracy: 0.6840
#
# Epoch 00050: loss did not improve from 0.87150
# Epoch 51/100
# 52/52 [==============================] - 27s 514ms/step - loss: 0.8379 - accuracy: 0.6925
#
# Epoch 00051: loss improved from 0.87150 to 0.83786, saving model to ./51-0.84.h5
# Epoch 52/100
# 52/52 [==============================] - 27s 513ms/step - loss: 0.8629 - accuracy: 0.6713
#
# Epoch 00052: loss did not improve from 0.83786
# Epoch 53/100
# 52/52 [==============================] - 27s 510ms/step - loss: 0.8865 - accuracy: 0.6755
#
# Epoch 00053: loss did not improve from 0.83786
# Epoch 54/100
# 52/52 [==============================] - 27s 513ms/step - loss: 0.8805 - accuracy: 0.6907
#
# Epoch 00054: loss did not improve from 0.83786
# Epoch 55/100
# 52/52 [==============================] - 27s 511ms/step - loss: 0.8118 - accuracy: 0.7052
#
# Epoch 00055: loss improved from 0.83786 to 0.81184, saving model to ./55-0.81.h5
# Epoch 56/100
# 52/52 [==============================] - 27s 514ms/step - loss: 0.7812 - accuracy: 0.7161
#
# Epoch 00056: loss improved from 0.81184 to 0.78122, saving model to ./56-0.78.h5
# Epoch 57/100
# 52/52 [==============================] - 27s 518ms/step - loss: 0.7829 - accuracy: 0.7197
#
# Epoch 00057: loss did not improve from 0.78122
# Epoch 58/100
# 52/52 [==============================] - 27s 512ms/step - loss: 0.8377 - accuracy: 0.6846
#
# Epoch 00058: loss did not improve from 0.78122
# Epoch 59/100
# 52/52 [==============================] - 27s 512ms/step - loss: 0.9124 - accuracy: 0.6640
#
# Epoch 00059: loss did not improve from 0.78122
# Epoch 60/100
# 52/52 [==============================] - 27s 513ms/step - loss: 0.8384 - accuracy: 0.6907
#
# Epoch 00060: loss did not improve from 0.78122
# Epoch 61/100
# 52/52 [==============================] - 27s 518ms/step - loss: 0.7971 - accuracy: 0.7016
#
# Epoch 00061: loss did not improve from 0.78122
# Epoch 62/100
# 52/52 [==============================] - 27s 516ms/step - loss: 0.8403 - accuracy: 0.6901
#
# Epoch 00062: loss did not improve from 0.78122
# Epoch 63/100
# 52/52 [==============================] - 27s 515ms/step - loss: 0.8464 - accuracy: 0.6870
#
# Epoch 00063: loss did not improve from 0.78122
# Epoch 64/100
# 52/52 [==============================] - 27s 513ms/step - loss: 0.8199 - accuracy: 0.7052
#
# Epoch 00064: loss did not improve from 0.78122
# Epoch 65/100
# 52/52 [==============================] - 27s 512ms/step - loss: 0.7387 - accuracy: 0.7343
#
# Epoch 00065: loss improved from 0.78122 to 0.73865, saving model to ./65-0.74.h5
# Epoch 66/100
# 52/52 [==============================] - 27s 515ms/step - loss: 0.7572 - accuracy: 0.7246
#
# Epoch 00066: loss did not improve from 0.73865
# Epoch 67/100
# 52/52 [==============================] - 27s 512ms/step - loss: 0.9567 - accuracy: 0.6586
#
# Epoch 00067: loss did not improve from 0.73865
# Epoch 68/100
# 52/52 [==============================] - 27s 512ms/step - loss: 1.0508 - accuracy: 0.6077
#
# Epoch 00068: loss did not improve from 0.73865
# Epoch 69/100
# 52/52 [==============================] - 27s 514ms/step - loss: 0.9320 - accuracy: 0.6713
#
# Epoch 00069: loss did not improve from 0.73865
# Epoch 70/100
# 52/52 [==============================] - 27s 517ms/step - loss: 0.8542 - accuracy: 0.6810
#
# Epoch 00070: loss did not improve from 0.73865
# Epoch 71/100
# 52/52 [==============================] - 27s 517ms/step - loss: 0.8166 - accuracy: 0.7028
#
# Epoch 00071: loss did not improve from 0.73865
# Epoch 72/100
# 52/52 [==============================] - 27s 515ms/step - loss: 0.7816 - accuracy: 0.7100
#
# Epoch 00072: loss did not improve from 0.73865
# Epoch 73/100
# 52/52 [==============================] - 27s 513ms/step - loss: 0.8832 - accuracy: 0.6762
#
# Epoch 00073: loss did not improve from 0.73865
# Epoch 74/100
# 52/52 [==============================] - 27s 514ms/step - loss: 0.8677 - accuracy: 0.6774
#
# Epoch 00074: loss did not improve from 0.73865
# Epoch 75/100
# 52/52 [==============================] - 27s 514ms/step - loss: 0.8019 - accuracy: 0.6961
#
# Epoch 00075: loss did not improve from 0.73865
# Epoch 76/100
# 52/52 [==============================] - 27s 513ms/step - loss: 0.7426 - accuracy: 0.7173
#
# Epoch 00076: loss did not improve from 0.73865
# Epoch 77/100
# 52/52 [==============================] - 27s 513ms/step - loss: 0.6825 - accuracy: 0.7439
#
# Epoch 00077: loss improved from 0.73865 to 0.68248, saving model to ./77-0.68.h5
# Epoch 78/100
# 52/52 [==============================] - 27s 516ms/step - loss: 0.6796 - accuracy: 0.7530
#
# Epoch 00078: loss improved from 0.68248 to 0.67960, saving model to ./78-0.68.h5
# Epoch 79/100
# 52/52 [==============================] - 27s 515ms/step - loss: 0.6425 - accuracy: 0.7597
#
# Epoch 00079: loss improved from 0.67960 to 0.64251, saving model to ./79-0.64.h5
# Epoch 80/100
# 52/52 [==============================] - 27s 517ms/step - loss: 0.6461 - accuracy: 0.7530
#
# Epoch 00080: loss did not improve from 0.64251
# Epoch 81/100
# 52/52 [==============================] - 27s 513ms/step - loss: 0.6441 - accuracy: 0.7464
#
# Epoch 00081: loss did not improve from 0.64251
# Epoch 82/100
# 52/52 [==============================] - 27s 514ms/step - loss: 0.5748 - accuracy: 0.7875
#
# Epoch 00082: loss improved from 0.64251 to 0.57479, saving model to ./82-0.57.h5
# Epoch 83/100
# 52/52 [==============================] - 27s 516ms/step - loss: 0.5846 - accuracy: 0.7809
#
# Epoch 00083: loss did not improve from 0.57479
# Epoch 84/100
# 52/52 [==============================] - 27s 516ms/step - loss: 0.6012 - accuracy: 0.7839
#
# Epoch 00084: loss did not improve from 0.57479
# Epoch 85/100
# 52/52 [==============================] - 27s 514ms/step - loss: 0.5932 - accuracy: 0.7893
#
# Epoch 00085: loss did not improve from 0.57479
# Epoch 86/100
# 52/52 [==============================] - 27s 514ms/step - loss: 0.6084 - accuracy: 0.7845
#
# Epoch 00086: loss did not improve from 0.57479
# Epoch 87/100
# 52/52 [==============================] - 27s 514ms/step - loss: 0.5519 - accuracy: 0.8027
#
# Epoch 00087: loss improved from 0.57479 to 0.55190, saving model to ./87-0.55.h5
# Epoch 88/100
# 52/52 [==============================] - 27s 517ms/step - loss: 0.5780 - accuracy: 0.7821
#
# Epoch 00088: loss did not improve from 0.55190
# Epoch 89/100
# 52/52 [==============================] - 27s 518ms/step - loss: 0.5527 - accuracy: 0.8069
#
# Epoch 00089: loss did not improve from 0.55190
# Epoch 90/100
# 52/52 [==============================] - 27s 517ms/step - loss: 0.4858 - accuracy: 0.8208
#
# Epoch 00090: loss improved from 0.55190 to 0.48578, saving model to ./90-0.49.h5
# Epoch 91/100
# 52/52 [==============================] - 27s 517ms/step - loss: 0.5136 - accuracy: 0.8111
#
# Epoch 00091: loss did not improve from 0.48578
# Epoch 92/100
# 52/52 [==============================] - 28s 528ms/step - loss: 0.5476 - accuracy: 0.8002
#
# Epoch 00092: loss did not improve from 0.48578
# Epoch 93/100
# 52/52 [==============================] - 28s 530ms/step - loss: 0.5374 - accuracy: 0.8051
#
# Epoch 00093: loss did not improve from 0.48578
# Epoch 94/100
# 52/52 [==============================] - 27s 522ms/step - loss: 0.5031 - accuracy: 0.8184
#
# Epoch 00094: loss did not improve from 0.48578
# Epoch 95/100
# 52/52 [==============================] - 28s 529ms/step - loss: 0.5233 - accuracy: 0.8057
#
# Epoch 00095: loss did not improve from 0.48578
# Epoch 96/100
# 52/52 [==============================] - 28s 525ms/step - loss: 0.4640 - accuracy: 0.8323
#
# Epoch 00096: loss improved from 0.48578 to 0.46397, saving model to ./96-0.46.h5
# Epoch 97/100
# 52/52 [==============================] - 27s 522ms/step - loss: 0.5020 - accuracy: 0.8081
#
# Epoch 00097: loss did not improve from 0.46397
# Epoch 98/100
# 52/52 [==============================] - 27s 516ms/step - loss: 0.4801 - accuracy: 0.8287
#
# Epoch 00098: loss did not improve from 0.46397
# Epoch 99/100
# 52/52 [==============================] - 27s 516ms/step - loss: 0.4672 - accuracy: 0.8232
#
# Epoch 00099: loss did not improve from 0.46397
# Epoch 100/100
# 52/52 [==============================] - 27s 519ms/step - loss: 0.5240 - accuracy: 0.8111
#
# Epoch 00100: loss did not improve from 0.46397

# %%
model.save('dev_machine_resnet_model.h5')
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

def search(dirname):
    img_list = []
    for (path, dir, files) in os.walk(dirname):
        for filename in files:
            ext = os.path.splitext(filename)[-1]
            if ext == '.jpg':
                img_list.append(path+'/'+filename)
    return img_list

# load and prepare the image
def load_image(filename):
    # load the image
    img = load_img(filename, target_size=(227, 227))
    # convert to array
    img = img_to_array(img)
    # reshape into a single sample with 3 channels
    img = np.expand_dims(img, axis=0)
    # img scaling
    img /= 255

    return img

# %%
img_list_1 = search('/content/drive/MyDrive/dev_machinelearning/test/0')

model = load_model('./dev_machine_resnet_model.h5')

# %%
import csv

with open('/content/drive/MyDrive/test_answer_sample_.csv', 'w') as csvfile:
    cwriter = csv.writer(csvfile)

    for i in range(len(img_list_1)+1):
      if i == 0:
        cwriter.writerow([' ','answer value'])
      else:
        img = load_image(img_list_1[i-1])
        result = model.predict(img)
        preds_value = np.argmax(result, axis=-1)[0]
        cwriter.writerow([i-1, preds_value])
